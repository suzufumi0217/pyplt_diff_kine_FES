# %%
import pandas as pd
diff_kine_FES = pd.read_excel("Diff_kine_FES.xlsx",usecols = range(1,7), skiprows = [20,21])

# %%
diff_kine_FES
# Out:
#     diff_R_T3  diff_R_T1  diff_R_TE  diff_L_T3  diff_L_T1  diff_L_TE
# 0    0.038100  -0.034250  -0.098900   0.240700  -0.028900  -0.219500
# 1    0.266500  -0.023450  -0.090900   0.290900  -0.036000  -1.006800
# 2    0.101300  -0.065600  -0.088400   0.246000  -0.043700  -0.254200
# 3    0.306000   0.025800  -0.268400   0.229400  -0.102400  -0.226900
# 4    0.026200   0.111650  -0.391100   0.291200  -0.010500  -0.175000
# 5    0.113600  -0.026150  -0.103400   0.342400  -0.059350  -0.200800
# 6    0.102100   0.040450  -0.210900   0.187200  -0.047250  -0.636500
# 7    0.107200  -0.049100  -0.117000   0.182100  -0.047500  -0.208000
# 8    0.112900  -0.026500  -0.116900   0.147700  -0.006700  -1.273700
# 9    0.108700  -0.036200  -0.285400   0.143500  -0.003650  -0.303700
# 10   0.097200  -0.007050  -0.105700   0.228700   0.051950  -0.655200
# 11   0.078100  -0.046400  -0.121700   0.200200  -0.032050  -0.337100
# 12   0.052900  -0.006900  -0.321200   0.137500  -0.029400  -0.262500
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

R_T3 = diff_kine_FES['diff_R_T3']
R_T1 = diff_kine_FES['diff_R_T1']
R_TE = diff_kine_FES['diff_R_TE']

bins = np.arange(-1,1.05,0.05)

plt.hist([R_T3, R_T1, R_TE], bins, label=["R_T3", "R_T1", "R_TE"])
# plt.hist(R_T1, bins,  alpha = 0.5, label='R_T1')
# plt.hist(R_TE, bins, alpha = 0.5, label="R_TE")
plt.legend(loc='upper left')

plt.show()

# %%
L_T3 = diff_kine_FES['diff_L_T3']
L_T1 = diff_kine_FES['diff_L_T1']
L_TE = diff_kine_FES['diff_L_TE']

bins = np.arange(-2,2.05,0.05)

plt.hist([L_T3, L_T1, L_TE], bins, label=["L_T3", "L_T1", "L_TE"])
# plt.hist(R_T1, bins,  alpha = 0.5, label='R_T1')
# plt.hist(R_TE, bins, alpha = 0.5, label="R_TE")
plt.legend(loc='upper left')

plt.show()
